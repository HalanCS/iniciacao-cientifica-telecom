# %%
import pandas as pd

# %%
# inventory archives
arq_prestadoras = "C:\\Users\\Cliente\\OneDrive\\Documentos\\ic_telecom\\anatel\\inventario de base de dados\\prestadoras_servicos_telecomunicacoes.csv"
arq_inventDB = "C:\\Users\\Cliente\\OneDrive\\Documentos\\ic_telecom\\anatel\\inventario de base de dados\\Inventario_de_Bases_de_Dados.csv"

# %%
# arquivos comparadores
arq_compAbran = "C:\\Users\\Cliente\\OneDrive\\Documentos\\ic_telecom\\anatel\\comparador\\ofertas_comparador_area_abrangencia.csv"
arq_compG = "C:\\Users\\Cliente\\OneDrive\\Documentos\\ic_telecom\\anatel\\comparador\\ofertas_comparador_geral.csv"
arq_compGI = "C:\\Users\\Cliente\\OneDrive\\Documentos\\ic_telecom\\anatel\\comparador\\ofertas_comparador_geral_inativo.csv"
arq_compScm = "C:\\Users\\Cliente\\OneDrive\\Documentos\\ic_telecom\\anatel\\comparador\\ofertas_comparador_scm.csv"
arq_compScmI = "C:\\Users\\Cliente\\OneDrive\\Documentos\\ic_telecom\\anatel\\comparador\\ofertas_comparador_scm_inativo.csv"
arq_compSeac = "C:\\Users\\Cliente\\OneDrive\\Documentos\\ic_telecom\\anatel\\comparador\\ofertas_comparador_seac.csv"
arq_compSeacI = "C:\\Users\\Cliente\\OneDrive\\Documentos\\ic_telecom\\anatel\\comparador\\ofertas_comparador_seac_inativo.csv"
arq_compSmpC = "C:\\Users\\Cliente\\OneDrive\\Documentos\\ic_telecom\\anatel\\comparador\\ofertas_comparador_smp_controle.csv"
arq_compSmpCI = "C:\\Users\\Cliente\\OneDrive\\Documentos\\ic_telecom\\anatel\\comparador\\ofertas_comparador_smp_controle_inativo.csv"
arq_compSmpP = "C:\\Users\\Cliente\\OneDrive\\Documentos\\ic_telecom\\anatel\\comparador\\ofertas_comparador_smp_pos.csv"
arq_compSmpPI = "C:\\Users\\Cliente\\OneDrive\\Documentos\\ic_telecom\\anatel\\comparador\\ofertas_comparador_smp_pos_inativo.csv"
arq_compSmpPre = "C:\\Users\\Cliente\\OneDrive\\Documentos\\ic_telecom\\anatel\\comparador\\ofertas_comparador_smp_pre.csv"
arq_compSmpPreI = "C:\\Users\\Cliente\\OneDrive\\Documentos\\ic_telecom\\anatel\\comparador\\ofertas_comparador_smp_pre_inativo.csv"
arq_compStfc = "C:\\Users\\Cliente\\OneDrive\\Documentos\\ic_telecom\\anatel\\comparador\\ofertas_comparador_stfc.csv"
arq_compStfcI = "C:\\Users\\Cliente\\OneDrive\\Documentos\\ic_telecom\\anatel\\comparador\\ofertas_comparador_stfc_inativo.csv"

# %%
# contracts archives
arq_contComp = "C:\\Users\\Cliente\\OneDrive\\Documentos\\ic_telecom\\anatel\\contratos\\contratos_compartilhamento.csv"
arq_contInter = "C:\\Users\\Cliente\\OneDrive\\Documentos\\ic_telecom\\anatel\\contratos\\contratos_compartilhamento.csv"
arq_contMVNO = "C:\\Users\\Cliente\\OneDrive\\Documentos\\ic_telecom\\anatel\\contratos\\contratos_mvno.csv"
arq_contRan = "C:\\Users\\Cliente\\OneDrive\\Documentos\\ic_telecom\\anatel\\contratos\\contratos_ran_sharing.csv"
arq_contCredVi = "C:\\Users\\Cliente\\OneDrive\\Documentos\\ic_telecom\\anatel\\contratos\\empresas_credenciadas_vigentes.csv"

# %%
# creating df db inventory
prestadoras = pd.read_csv(arq_prestadoras, sep=';', low_memory=False)
inventDB = pd.read_csv(arq_inventDB, encoding='ISO-8859-1', sep=';')

# %%
# Creating df's for comparators
compAbran = pd.read_csv(arq_compAbran, sep=';', encoding='ISO-8859-1')
compG = pd.read_csv(arq_compG, sep=';', encoding='ISO-8859-1')
compGI = pd.read_csv(arq_compGI, sep=';', encoding='ISO-8859-1')
compScm = pd.read_csv(arq_compScm, sep=';', encoding='ISO-8859-1')
compScmI = pd.read_csv(arq_compScmI, sep=';', encoding='ISO-8859-1')
compSeac = pd.read_csv(arq_compSeac, sep=';', encoding='ISO-8859-1')
compSeacI = pd.read_csv(arq_compSeacI, sep=';', encoding='ISO-8859-1', low_memory=False)
compSmpC = pd.read_csv(arq_compSmpC, sep=';', encoding='ISO-8859-1')
compSmpCI = pd.read_csv(arq_compSmpCI, sep=';', encoding='ISO-8859-1')
compSmpP = pd.read_csv(arq_compSmpP, sep=';', encoding='ISO-8859-1')
compSmpPI = pd.read_csv(arq_compSmpPI, sep=';', encoding='ISO-8859-1')
compSmpPre = pd.read_csv(arq_compSmpPre, sep=';', encoding='ISO-8859-1')
compSmpPreI = pd.read_csv(arq_compSmpPreI, sep=';', encoding='ISO-8859-1')
compStfc = pd.read_csv(arq_compStfc, sep=';', encoding='ISO-8859-1')
compStfcI = pd.read_csv(arq_compStfcI, sep=';', encoding='ISO-8859-1')

# %%
# Creating df's for contracts
contComp = pd.read_csv(arq_contComp, sep=';', encoding='ISO-8859-1')
contInter = pd.read_csv(arq_contInter, sep=';', encoding='ISO-8859-1')
contMVNO = pd.read_csv(arq_contMVNO, sep=';', encoding='ISO-8859-1')
contRan = pd.read_csv(arq_contRan, sep=';', encoding='ISO-8859-1')
contCredVi = pd.read_csv(arq_contCredVi, sep=';', encoding='ISO-8859-1')

# %%
df_contracts = [
    ('contComp', contComp),
    ('contInter', contInter),
    ('contMVNO', contMVNO),
    ('contRan', contRan),
    ('contCredVi', contCredVi)
]

# %%
# List of all DataFrames and their respective names
df_comparators = [
    ('compAbran', compAbran),
    ('compG', compG),
    ('compGI', compGI),
    ('compScm', compScm),
    ('compScmI', compScmI),
    ('compSeac', compSeac),
    ('compSeacI', compSeacI),
    ('compSmpC', compSmpC),
    ('compSmpCI', compSmpCI),
    ('compSmpP', compSmpP),
    ('compSmpPI', compSmpPI),
    ('compSmpPre', compSmpPre),
    ('compSmpPreI', compSmpPreI),
    ('compStfc', compStfc),
    ('compStfcI', compStfcI)
]

# Loop through all DataFrames and rename the columns
for name, df in df_comparators:
    # Rename the column if 'ï»¿ID_GERAL' exists in the DataFrame
    if 'ï»¿ID_GERAL' in df.columns:
        df.rename(columns={'ï»¿ID_GERAL': 'ID_GERAL'}, inplace=True)

# Now each DataFrame has had the column renamed where necessary

# %%
compGI.isna().sum()
# Out:
# ID_GERAL                            0
# TIPO_OFERTA                         0
# OFERTA_SCM_INCLUSO                  0
# CODIGO_OFERTA_SCM_INCLUSO      113529
# OFERTA_SMP_INCLUSO                  0
# CODIGO_OFERTA_SMP_INCLUSO      178310
# OFERTA_STFC_INCLUSO                 0
# CODIGO_OFERTA_STFC_INCLUSO     195847
# OFERTA_SEAC_INCLUSO                 0
# CODIGO_OFERTA_SEAC_INCLUSO     182896
# NOME_PRESTADORA                     0
# NOME_OFERTA                         0
# CODIGO_OFERTA                     326
# ETIQUETA_OFERTA                     0
# LINK_SITE                           0
# DATA_INICIO_OFERTA                  0
# DATA_FIM_OFERTA                     0
# TEMPO_FIDELIZACAO              493654
# DESCONTO_FIDELIZACAO          1362570
# TEMPO_DESCONTO_FIDELIZACAO    1624758
# BENEFICIO_FIDELIZACAO          542114
# MULTA_FIDELIZACAO              537398
# DESCONTO_PAGAMENTO             242457
# FORMA_PAGAMENTO                181088
# DESTAQUE_OFERTA                 28953
# ...

# %%
for name, df in df_contracts:
    print(f'{name}: {df.shape}')
# Out:
# contComp: (8758, 11)
# contInter: (8758, 11)
# contMVNO: (269, 13)
# contRan: (16, 20)
# contCredVi: (166, 2)

# %%
contInter
# Out:
#      ï»¿ACORDO_TIPO PROTOCOLO_DATA       PROCESSO_ANATEL  \
# 0          CONTRATO     22/04/2013  53500.009204/2013-64
# 1          CONTRATO     02/05/2013  53500.011549/2013-88
# 2          CONTRATO     06/05/2013  53500.011548/2013-33
# 3          CONTRATO     06/05/2013  53500.012976/2013-83
# 4          CONTRATO     06/05/2013  53500.012976/2013-83
# ...             ...            ...                   ...
# 8753       CONTRATO     24/04/2024  53500.035601/2024-44
# 8754       CONTRATO     24/04/2024  53500.035601/2024-44
# 8755       CONTRATO     27/05/2024  53500.045448/2024-63
# 8756       CONTRATO     27/05/2024  53500.045448/2024-63
# 8757       CONTRATO     27/05/2024  53500.045448/2024-63
#
#                                      DETENTORA  DETENTORA_CNPJ  \
# 0          LIGHT SERVIÃOS DE ELETRICIDADE S.A    6.044444e+13
# 1      CAIUÃ - DISTRIBUIÃÃO DE ENERGIA S.A.    7.282377e+12
# 2      CAIUÃ - DISTRIBUIÃÃO DE ENERGIA S.A.    7.282377e+12
# ...
