# %%
import pandas as pd

# %%
arq_portabilidade = "C:\\Users\\Cliente\\OneDrive\\Documentos\\ic_telecom\\anatel\\portabilidade\\CSV_PORTABILIDADE.csv"
arq_saldo = "C:\\Users\\Cliente\\OneDrive\\Documentos\\ic_telecom\\anatel\\portabilidade\\CSV_SALDO.csv"

# %%
# transformando em dataframes do pandas

df_portabilidade = pd.read_csv(arq_portabilidade, sep=';')
df_saldo = pd.read_csv(arq_saldo, sep=';')

# %%
# visucalizacao dos dados
df_portabilidade.head()
# Out:
#    NU_CNPJ_DOADORA NO_PRESTADORA_DOADORA  NU_CNPJ_RECEPTORA  \
# 0   76535764000143               OI S.A.      2558157000162
# 1   76535764000143               OI S.A.      2558157000162
# 2   76535764000143               OI S.A.      2558157000162
# 3   76535764000143               OI S.A.      2558157000162
# 4   76535764000143               OI S.A.      2558157000162
#
#   NO_PRESTADORA_RECEPTORA  AA_EFETIVACAO  MM_EFETIVACAO AM_EFETIVACAO  \
# 0       TELEFONICA BRASIL           2008              9       2008-09
# 1       TELEFONICA BRASIL           2008              9       2008-09
# 2       TELEFONICA BRASIL           2008              9       2008-09
# 3       TELEFONICA BRASIL           2008             12       2008-12
# 4       TELEFONICA BRASIL           2008             12       2008-12
#
#   DT_EFETIVACAO  NU_SERVICO SG_SERVICO  CO_CN SG_UF  \
# 0    01/09/2008         171       STFC     43    PR
# 1    01/09/2008         171       STFC     62    GO
# 2    01/09/2008         171       STFC     67    MS
# 3    01/12/2008         171       STFC     43    PR
# 4    01/12/2008         171       STFC     44    PR
#
#    QT_PORTABILIDADE_EFETIVADA
# 0                         365
# 1                        1019
# 2                         564
# 3                         391
# 4                        1478

# %%
# exclusao dos dados desnecessarios
df_portabilidade = df_portabilidade.drop()

# %%
# visualizacao dos dados
df_saldo.head()
# Out:
#           NU_CNPJ                      NO_PRESTADORA  ID_DT_EFETIVACAO  \
# 0  40432544000147                         CLARO S.A.          20230401
# 1   2421421000111                            TIM S A          20150601
# 2  76535764000143  OI S.A. - EM RECUPERACAO JUDICIAL          20110201
# 3   1371416000189     SERCOMTEL S/A TELECOMUNICACOES          20111201
# 4  11208525000133        LIGUE TELECOM SERVICOS LTDA          20141001
#
#   DT_EFETIVACAO  AA_FORMATADA  MM_FORMATADA AM_FORMATADA  NU_SERVICO  \
# 0    01/04/2023          2023             4      2023-04          10
# 1    01/06/2015          2015             6      2015-06          10
# 2    01/02/2011          2011             2      2011-02          10
# 3    01/12/2011          2011            12      2011-12          10
# 4    01/10/2014          2014            10      2014-10         171
#
#   SG_SERVICO  CO_CN SG_UF               NO_UF  QT_PORTABILIDADE_DOADO  \
# 0        SMP     67    MS  Mato Grosso do Sul                    1566
# 1        SMP     77    BA               Bahia                      23
# 2        SMP     68    AC                Acre                      67
# 3        SMP     43    PR              Paraná                     221
# 4       STFC     44    PR              Paraná                      32
#
#    QT_PORTABILIDADE_RECEBIDO  QT_SALDO
# 0                       2356       790
# 1                          6       -17
# 2                         79        12
# 3                         58      -163
# 4                         36         4
